# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import sys
for x in reversed(range(len(sys.path))):
    if "ros" in sys.path[x]:
        sys.path.pop(x)

import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
text = ""
with open("/home/susung/ros_workspace/src/hospitality/hospitality_server/test/path.txt", "r") as fp:
    text = fp.read()
image = cv2.imread("/home/susung/ros_workspace/src/hospitality/hospitality_server/data/map/map_floor_001.bmp")

# %%
data = [[int(y[0]), int(y[1])] for y in [z.split(' ') for z in [x.strip() for x in text.split('\n')][1:-1]]]

# %%
arr = np.array(data)

# %%
plt.figure(1, figsize=[15,15])
plt.imshow(image)
plt.plot(arr[:,1], arr[:,0])
